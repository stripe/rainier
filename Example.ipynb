// %%
interp.repositories() ::= coursier.MavenRepository("https://dl.bintray.com/cibotech/public/")

// %%
import $ivy.`com.stripe::rainier-plot:0.2.2`
import com.stripe.rainier.core._
import com.stripe.rainier.repl._
import com.stripe.rainier.plot.Jupyter._
// Out:
// import $ivy.$
//
// import com.stripe.rainier.core._
//
// import com.stripe.rainier.repl._
//
// import com.stripe.rainier.plot.Jupyter._

// %%
val model = for {
  x <- Normal.standard.param
  y <- Uniform(0, x).param
} yield Map("x" -> x, "y" -> y)

pairs(model.sample())
// Out:
// model: RandomVariable[Map[String, com.stripe.rainier.compute.Real]] = com.stripe.rainier.core.RandomVariable@ef1c379
